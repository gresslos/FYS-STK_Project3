# %% [markdown]
# # Importing the data

# %% [markdown]
# ## Import Libraries

# %%
# import system libraries
import os
import gc
import itertools
from PIL import Image
import cv2
from matplotlib.image import imread

# import data handling tools
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')

from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import KFold


# import Deep Learning Libraries
import tensorflow as tf
from tensorflow.keras import regularizers 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout, Input
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import img_to_array, array_to_img
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import warnings
warnings.filterwarnings('ignore')

figsize = (20, 8)
fontsize = 20
lablesize = 14
# Out:
# 2024-11-21 10:16:21.929159: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-11-21 10:16:22.100867: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1732180582.158568     885 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1732180582.175813     885 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-21 10:16:22.362298: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession
config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)
# Out:
# I0000 00:00:1732180584.246256     885 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9558 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
data_dir = 'Bird_Species_Dataset' 
#the code file should be in the same folder as the folder called 'Bird Species Dataset' thus this is the path to the folder containing the dataset
filepaths, image_list, label_list = [], [], []

folders = os.listdir(data_dir)

#print(folders)

for fold in folders:
    foldpath = os.path.join(data_dir, fold)
    flist = os.listdir(foldpath)
    for f in flist:
        fpath = os.path.join(foldpath, f)
        filepaths.append(fpath)
        label_list.append(fold)

print(filepaths)
print(label_list)

for file in filepaths:
    image = cv2.imread(file)
    image = img_to_array(image)
    image_list.append(image)
    
# Concatenate data paths with labels into one dataframe
Fseries = pd.Series(filepaths, name='filepaths')
Lseries = pd.Series(label_list, name='labels')
df = pd.concat([Fseries, Lseries], axis=1)
# Out:
# ['Bird_Species_Dataset/DOWNY WOODPECKER/092.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/060.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/090.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/057.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/011.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/071.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/034.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/074.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/111.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/029.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/108.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/127.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/061.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/035.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/102.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/041.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/082.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/077.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/053.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/066.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/115.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/104.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/044.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/068.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/049.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/079.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/025.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/133.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/064.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/059.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/023.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/137.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/116.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/098.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/036.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/124.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/105.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/040.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/076.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/046.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/097.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/042.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/112.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/096.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/132.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/050.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/024.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/032.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/086.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/026.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/021.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/091.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/126.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/045.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/136.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/067.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/009.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/055.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/075.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/039.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/120.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/078.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/130.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/128.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/135.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/017.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/107.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/052.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/070.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/113.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/005.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/080.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/123.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/117.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/038.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/099.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/058.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/006.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/007.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/014.jpg', 'Bird_Species_Dataset/DOWNY WOODPECKER/065.jpg', 'Bird_Species_Dataset/DOWNY WO ...
# ['DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'DOWNY WOODPECKER', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', 'FLAMINGO', ...

# %%
df['labels'].value_counts()
# Out:
# labels
# AMERICAN GOLDFINCH    143
# EMPEROR PENGUIN       139
# DOWNY WOODPECKER      137
# FLAMINGO              132
# CARMINE BEE-EATER     131
# BARN OWL              129
# Name: count, dtype: int64

# %%
np.shape(image_list)
# Out:
# (811, 224, 224, 3)

# %% [markdown]
# ### Plot bird-pictures

# %%
num_images = 2

# Get unique bird species labels
bird_species = df['labels'].unique()

# Set up the plot
plt.figure(figsize=(6, 10))

# Loop through each bird species
for idx, bird in enumerate(bird_species):
    # Filter the DataFrame to get file paths for this bird species
    bird_df = df[df['labels'] == bird].sample(num_images)  # Get a random sample of 16 images
    
    # Loop through the 16 images and plot them
    for i, file in enumerate(bird_df['filepaths'].values):
        plt.subplot(len(bird_species), num_images, idx * num_images + i + 1)
        img = Image.open(file)
        plt.imshow(img)
        plt.axis('off')
        plt.title(bird)
        
# Show the plot
plt.tight_layout()
plt.savefig("CNN_plots/birds.png")

# %% [markdown]
# ### Splitting Data

# %%
"""# Splitting dataset
strat = df['labels']
train_df, dummy_df = train_test_split(df, test_size=.3, shuffle=True, stratify=strat, random_state=123)

# valid and test dataframe
strat = dummy_df['labels']
valid_df, test_df = train_test_split(dummy_df, test_size=.5, shuffle=True, stratify=strat, random_state=123)"""

# Splitting dataset
strat = df['labels']
train_df, test_df = train_test_split(df, test_size=.3, shuffle=True, stratify=strat, random_state=123)


print(f"Number of Training dataset: {len(train_df)}\nNumber of Testing dataset: {len(test_df)}")

# NOTE: stratify = strat -> equal proportions of bird-labels in each data-substet (Train/Test/Val) as original data
# Out:
# Number of Training dataset: 567
# Number of Testing dataset: 244

# %% [markdown]
# ### Change input to **ImageDataGenerator** objects

# %%
# crobed image size
batch_size_IDG = 8
img_size = (224, 224)
channels = 3
img_shape = (img_size[0], img_size[1], channels)

tr_gen = ImageDataGenerator()
ts_gen = ImageDataGenerator()


train_gen = tr_gen.flow_from_dataframe(train_df, x_col='filepaths', y_col='labels', target_size=img_size, class_mode='categorical', 
                                       color_mode='rgb', shuffle= True, batch_size=batch_size_IDG)

test_gen = ts_gen.flow_from_dataframe(test_df, x_col='filepaths', y_col='labels', target_size=img_size, class_mode='categorical',
                                     color_mode='rgb', shuffle=False, batch_size=batch_size_IDG)


print(tr_gen)
# Out:
# Found 567 validated image filenames belonging to 6 classes.
# Found 244 validated image filenames belonging to 6 classes.
# <keras.src.legacy.preprocessing.image.ImageDataGenerator object at 0x7fc2b795ae00>

# %% [markdown]
# ### Images Structure

# %%
# Create Model Structure
img_size = (224, 224)
channels = 3
img_shape = (img_size[0], img_size[1], channels)
class_count = len(list(train_gen.class_indices.keys()))

# %% [markdown]
# ## CNN function

# %%
def CNN(eta, lmbd, n_filters, n_conv, n_pool, n_neurons, act_func, optimizer, extra_dense_layers=None):
    model = Sequential([
        Conv2D(n_filters, (n_conv,n_conv), activation=act_func, padding='same', input_shape = img_shape, kernel_regularizer=regularizers.l2(lmbd)),
        MaxPooling2D((n_pool,n_pool)),

        Conv2D(n_filters*2, (n_conv,n_conv), activation=act_func, padding='same', kernel_regularizer=regularizers.l2(lmbd)),
        MaxPooling2D((n_pool*2,n_pool*2)),

        Conv2D(n_filters*4, (n_conv,n_conv), activation=act_func, padding='same', kernel_regularizer=regularizers.l2(lmbd)),
        MaxPooling2D((n_pool*4,n_pool*4)),
        #MaxPooling2D((n_pool,n_pool)),  # mark this in if too many #params
        
        Flatten(),
        Dense(n_neurons, activation=act_func, kernel_regularizer=regularizers.l2(lmbd)),
    ]) 

    # Add any additional dense layers specified in extra_dense_layers
    if extra_dense_layers:
        for i in range(extra_dense_layers):
            model.add(Dense(n_neurons, activation=act_func, kernel_regularizer=regularizers.l2(lmbd)))
        """for n_neurons in extra_dense_layers:
            model.add(Dense(n_neurons, activation=act_func, kernel_regularizer=regularizers.l2(lmbd)))"""
        
    
    # Add the final output layer for classification
    model.add(Dense(class_count, activation='softmax'))
    
    
    #model.compile(Adam(learning_rate = eta), loss = 'categorical_crossentropy', metrics=['acc'])
    model.compile(optimizer(learning_rate = eta), loss = 'categorical_crossentropy', metrics=['acc'])
    # NOTES: 
    # INFO: tf.keras.Sequential   -> look at: https://www.tensorflow.org/api_docs/python/tf/keras/Sequential

    # compile(...,  loss = 'categorical_crossentropy')  -> Computes the crossentropy loss between the labels and predictions.
    
    return model


early_stopping = EarlyStopping(
    patience=100,
    min_delta=0,
    mode=min,
    monitor='val_loss',
    verbose=0,
    restore_best_weights=True,
    baseline=None
)

# %% [markdown]
# ### Comparison $\lambda$ vs. $\eta$ with CNN model

# %%
# Set seed for reproducibility
seed = 2024
tf.keras.backend.clear_session()     # Clear any previous model session
tf.keras.utils.set_random_seed(seed) # must include for reproducibility 


# ------------------- K-Fold Cross Validation
n_splits = 5  # Number of k-folds
kf = KFold(n_splits=n_splits, shuffle=True, random_state=1)

# ------------------ Setting up parameters

# ---- Fixed Parameters trought project----
n_filters = 6
n_conv = 3
n_pool = 2
n_neurons = 50
epochs = 100 # Final training with epochs = 1000
# -----------------------------------------

batch_size = 10
act_func = 'relu'
optimizer = tf.keras.optimizers.Adam 
# Have implemented other optimizer for futere work
# if want to test with different otimizers, ex Adamax etc..

# %%
# Defining parameter-space to search for optimal fit
max_lmbd = -4
max_eta = -4
N_lmbd = abs(max_lmbd) + 1
N_eta = abs(max_eta) + 1

lmbd_list = np.logspace(max_lmbd, 0, N_lmbd)
lmbd_list[0] = 0 # setting first elemenent to include no L2-penalty
eta_list = np.logspace(max_eta, 0, N_eta)

print("lmbd = ", lmbd_list)
print("eta  = ", eta_list)


CNN_model_list = []
fit_list       = []
for lmbd in lmbd_list:
    for eta in eta_list:
        fold = 0
        fit  = []
        for train_idx, val_idx in kf.split(train_df): # performing K-Fold
            # Split the data
            tr_fold, v_fold = train_df.iloc[train_idx], train_df.iloc[val_idx]

            ID_tr_gen = ImageDataGenerator()
            ID_v_gen  =  ImageDataGenerator()
            train_fold = ID_tr_gen.flow_from_dataframe(tr_fold, x_col='filepaths', y_col='labels', target_size=img_size, class_mode='categorical', color_mode='rgb', shuffle= True, batch_size=batch_size_IDG)
            val_fold   = ID_v_gen.flow_from_dataframe(v_fold, x_col='filepaths', y_col='labels', target_size=img_size, class_mode='categorical', color_mode='rgb', shuffle= True, batch_size=batch_size_IDG)

            
            # Initialize a new model for each fold
            CNN_model = CNN(eta, lmbd, n_filters, n_conv, n_pool, n_neurons, act_func, optimizer)
            #print("------------------------- SUMMARY --------------------------")
            #CNN_model.summary()

            # Train on current fold
            print(f'\nFold {fold + 1} - lmbd = {lmbd}, eta = {eta}\n')
            fit_fold = CNN_model.fit(x= train_fold, epochs=epochs, batch_size=batch_size, validation_data=val_fold, verbose=0, callbacks=[early_stopping])
            
            fit.append(fit_fold)
            fold += 1
            tf.keras.backend.clear_session()
            gc.collect()

        # Save results
        fit_list.append([fit, lmbd, eta])
# Out:
# lmbd =  [0.    0.001 0.01  0.1   1.   ]
# eta  =  [1.e-04 1.e-03 1.e-02 1.e-01 1.e+00]
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
# I0000 00:00:1732180585.753323     885 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9558 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070, pci bus id: 0000:01:00.0, compute capability: 8.9
# Fold 1 - lmbd = 0.0, eta = 0.0001
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1732180586.801413    1095 service.cc:148] XLA service 0x7fc1ec045e30 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1732180586.801628    1095 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce RTX 4070, Compute Capability 8.9
# 2024-11-21 10:16:26.829276: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1732180586.914627    1095 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1732180588.270801    1095 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - lmbd = 0.0, eta = 0.0001
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - lmbd = 0.0, eta = 0.0001
# 2024-11-21 10:17:52.736503: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'loop_add_exponential_fusion', 80 bytes spill stores, 80 bytes spill loads
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - lmbd = 0.0, eta = 0.0001
# 2024-11-21 10:18:38.082643: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'loop_add_exponential_fusion', 80 bytes spill stores, 80 bytes spill loads
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - lmbd = 0.0, eta = 0.0001
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - lmbd = 0.0, eta = 0.001
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - lmbd = 0.0, eta = 0.001
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - lmbd = 0.0, eta = 0.001
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - lmbd = 0.0, eta = 0.001
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - lmbd = 0.0, eta = 0.001
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - lmbd = 0.0, eta = 0.01
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - lmbd = 0.0, eta = 0.01
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - lmbd = 0.0, eta = 0.01
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - lmbd = 0.0, eta = 0.01
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - lmbd = 0.0, eta = 0.01
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - lmbd = 0.0, eta = 0.1
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - lmbd = 0.0, eta = 0.1
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - lmbd = 0.0, eta = 0.1
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - lmbd = 0.0, eta = 0.1
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - lmbd = 0.0, eta = 0.1
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - lmbd = 0.0, eta = 1.0
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - lmbd = 0.0, eta = 1.0
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - lmbd = 0.0, eta = 1.0
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - lmbd = 0.0, eta = 1.0
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - lmbd = 0.0, eta = 1.0
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - lmbd = 0.001, eta = 0.0001
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - lmbd = 0.001, eta = 0.0001
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - lmbd = 0.001, eta = 0.0001
# 2024-11-21 10:34:32.635738: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'loop_add_exponential_fusion', 80 bytes spill stores, 80 bytes spill loads
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - lmbd = 0.001, eta = 0.0001
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - lmbd = 0.001, eta = 0.0001
# 2024-11-21 10:35:51.504143: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'loop_add_exponential_fusion', 80 bytes spill stores, 80 bytes spill loads
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - lmbd = 0.001, eta = 0.001
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - lmbd = 0.001, eta = 0.001
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - lmbd = 0.001, eta = 0.001
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - lmbd = 0.001, eta = 0.001
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - lmbd = 0.001, eta = 0.001
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - lmbd = 0.001, eta = 0.01
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - lmbd = 0.001, eta = 0.01
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - lmbd = 0.001, eta = 0.01
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - lmbd = 0.001, eta = 0.01
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - lmbd = 0.001, eta = 0.01
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - lmbd = 0.001, eta = 0.1
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - lmbd = 0.001, eta = 0.1
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - lmbd = 0.001, eta = 0.1
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - lmbd = 0.001, eta = 0.1
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - lmbd = 0.001, eta = 0.1
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - lmbd = 0.001, eta = 1.0
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - lmbd = 0.001, eta = 1.0
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - lmbd = 0.001, eta = 1.0
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - lmbd = 0.001, eta = 1.0
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - lmbd = 0.001, eta = 1.0
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - lmbd = 0.01, eta = 0.0001
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - lmbd = 0.01, eta = 0.0001
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - lmbd = 0.01, eta = 0.0001
# 2024-11-21 10:51:18.359535: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'loop_add_exponential_fusion', 80 bytes spill stores, 80 bytes spill loads
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - lmbd = 0.01, eta = 0.0001
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - lmbd = 0.01, eta = 0.0001
# 2024-11-21 10:52:40.110337: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'loop_add_exponential_fusion', 80 bytes spill stores, 80 bytes spill loads
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - lmbd = 0.01, eta = 0.001
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - lmbd = 0.01, eta = 0.001
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - lmbd = 0.01, eta = 0.001
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - lmbd = 0.01, eta = 0.001
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - lmbd = 0.01, eta = 0.001
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - lmbd = 0.01, eta = 0.01
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - lmbd = 0.01, eta = 0.01
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - lmbd = 0.01, eta = 0.01
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - lmbd = 0.01, eta = 0.01
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - lmbd = 0.01, eta = 0.01
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - lmbd = 0.01, eta = 0.1
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - lmbd = 0.01, eta = 0.1
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - lmbd = 0.01, eta = 0.1
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - lmbd = 0.01, eta = 0.1
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - lmbd = 0.01, eta = 0.1
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - lmbd = 0.01, eta = 1.0
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - lmbd = 0.01, eta = 1.0
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - lmbd = 0.01, eta = 1.0
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - lmbd = 0.01, eta = 1.0
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - lmbd = 0.01, eta = 1.0
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - lmbd = 0.1, eta = 0.0001
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - lmbd = 0.1, eta = 0.0001
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - lmbd = 0.1, eta = 0.0001
# 2024-11-21 11:08:12.532105: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'loop_add_exponential_fusion', 80 bytes spill stores, 80 bytes spill loads
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - lmbd = 0.1, eta = 0.0001
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - lmbd = 0.1, eta = 0.0001
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - lmbd = 0.1, eta = 0.001
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - lmbd = 0.1, eta = 0.001
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - lmbd = 0.1, eta = 0.001
# 2024-11-21 11:11:37.157348: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'loop_add_exponential_fusion', 80 bytes spill stores, 80 bytes spill loads
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - lmbd = 0.1, eta = 0.001
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - lmbd = 0.1, eta = 0.001
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - lmbd = 0.1, eta = 0.01
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - lmbd = 0.1, eta = 0.01
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - lmbd = 0.1, eta = 0.01
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - lmbd = 0.1, eta = 0.01
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - lmbd = 0.1, eta = 0.01
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - lmbd = 0.1, eta = 0.1
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - lmbd = 0.1, eta = 0.1
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - lmbd = 0.1, eta = 0.1
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - lmbd = 0.1, eta = 0.1
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - lmbd = 0.1, eta = 0.1
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - lmbd = 0.1, eta = 1.0
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - lmbd = 0.1, eta = 1.0
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - lmbd = 0.1, eta = 1.0
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - lmbd = 0.1, eta = 1.0
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - lmbd = 0.1, eta = 1.0
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - lmbd = 1.0, eta = 0.0001
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - lmbd = 1.0, eta = 0.0001
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - lmbd = 1.0, eta = 0.0001
# 2024-11-21 11:25:20.162081: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'loop_add_exponential_fusion', 80 bytes spill stores, 80 bytes spill loads
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - lmbd = 1.0, eta = 0.0001
# 2024-11-21 11:26:02.081687: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'loop_add_exponential_fusion', 80 bytes spill stores, 80 bytes spill loads
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - lmbd = 1.0, eta = 0.0001
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - lmbd = 1.0, eta = 0.001
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - lmbd = 1.0, eta = 0.001
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - lmbd = 1.0, eta = 0.001
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - lmbd = 1.0, eta = 0.001
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - lmbd = 1.0, eta = 0.001
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - lmbd = 1.0, eta = 0.01
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - lmbd = 1.0, eta = 0.01
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - lmbd = 1.0, eta = 0.01
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - lmbd = 1.0, eta = 0.01
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - lmbd = 1.0, eta = 0.01
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - lmbd = 1.0, eta = 0.1
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - lmbd = 1.0, eta = 0.1
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - lmbd = 1.0, eta = 0.1
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - lmbd = 1.0, eta = 0.1
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - lmbd = 1.0, eta = 0.1
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - lmbd = 1.0, eta = 1.0
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - lmbd = 1.0, eta = 1.0
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - lmbd = 1.0, eta = 1.0
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - lmbd = 1.0, eta = 1.0
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - lmbd = 1.0, eta = 1.0

# %% [markdown]
# ### Performance Scores: $\lambda$ vs. $\eta$

# %%
def plot_accuracy_evoluton(fit_list, string1, string2, png_name):
    plt.figure(figsize=figsize)
    plt.style.use('fivethirtyeight')

    # Loop through fit_list to plot each fit's validation accuracy
    for fit, var1, var2 in fit_list: 

        val_acc = np.mean([f.history['val_acc'] for f in fit], axis=0) # calculating mean val_acc for all folds
        if val_acc[-1] < 0.6: # not plot if last accuracy < 0.6
                continue  
        
        Epochs = [i+1 for i in range(len(val_acc))]

        if isinstance(var1, str):
            if isinstance(var2, str):
                plt.plot(Epochs, val_acc, label= f'{string1} = {var1}, {string2} = {var2}')
            else: 
                plt.plot(Epochs, val_acc, label= f'{string1} = {var1}, {string2} = {var2:g}')
        elif isinstance(var2, str):
            plt.plot(Epochs, val_acc, label= f'{string1} = {var1:3g}, {string2} = {var2}')
        elif isinstance(var2, list):
            plt.plot(Epochs, val_acc, label= f'{string1} = {var1:3g}, {string2} = {var2}')
        else:
            plt.plot(Epochs, val_acc, label= f'{string1} = {var1:3g}, {string2} = {var2}')


    plt.axhline(y=0.5, color='black', linestyle='--', linewidth=1, label='Cutoff') # cutoff, only include val_acc[-1] > cutoff = 0.5
    plt.suptitle(rf'CNN      -      Validation Accuracy   -   {string1}  vs. {string2}', fontsize=fontsize)
    plt.title(r"", fontsize=fontsize-5)
    plt.xlabel('Epochs', fontsize=lablesize)
    plt.ylabel('Accuracy', fontsize=lablesize)
    plt.legend(loc='upper left')

    plt.tight_layout
    plt.savefig("CNN_plots/" + png_name + ".png")



def plot_heatmap(fit_list, var1, var2, string1, string2, png_name):


    val_acc = [] # list with all accuracy scores for validation set    
    for fit, _, _ in fit_list:
        v_acc = np.mean([f.history['val_acc'] for f in fit], axis=0) # calculating mean val_acc for all folds
        val_acc.append(v_acc[-1])

    val_acc_heatmap = np.array(val_acc).reshape( (len(var1), len(var2)) )

    # Find index for maximum val_acc
    index_max_val_acc = np.argmax(val_acc_heatmap)
    index_max_2d = np.unravel_index(index_max_val_acc, val_acc_heatmap.shape)

    # Create heatmap
    plt.figure(figsize=(8, 6))
    plt.style.use('fivethirtyeight')

    sns.heatmap(val_acc_heatmap, annot=True, cmap="coolwarm", xticklabels=var2, yticklabels=var1)
    # Get the row and column to highlight highest accuracy
    # Draw lines around the specified cell
    row, col = index_max_2d
    plt.vlines(col, row, row + 1, color='yellow', linewidth=2)  # Left vertical
    plt.vlines(col + 1, row, row + 1, color='yellow', linewidth=2)  # Right vertical
    plt.hlines(row, col, col + 1, color='yellow', linewidth=2)  # Bottom horizontal
    plt.hlines(row + 1, col, col + 1, color='yellow', linewidth=2)  # Top horizontal

    plt.suptitle(r'CNN      -      Validation Accuracy', fontsize=fontsize)
    plt.title(rf"{string1}  vs. {string2}", fontsize=fontsize)
    plt.xlabel(rf"{string2}", fontsize = lablesize)
    plt.ylabel(rf"{string1}", fontsize = lablesize)

    plt.savefig("CNN_plots/" + png_name + ".png")

    return index_max_val_acc, index_max_2d

# %%
string1 = '$\lambda$'
string2 = '$\eta$'
png_name = 'val_acc_' + 'lambda' + "_" + 'eta'
plot_accuracy_evoluton(fit_list, string1, string2, png_name)


var1 = lmbd_list
var2 = eta_list
png_name = 'heatmap_val_acc' + 'lambda' + "_" + 'eta'
index_max_val_acc, index_max_2d =  plot_heatmap(fit_list, var1, var2, string1, string2, png_name)





# ---------------------------- Selecting optimal fit for lmbd vs. eta (according to Validation Accuracy)
# Save parameters for future use 
fit, lmbd, eta = fit_list[index_max_val_acc]
 
val_acc_optimal = np.mean([f.history['val_acc'] for f in fit], axis=0)[-1] # calculating mean val_acc for all folds

print("--------- Optimal Fit (according to Validation Accuracy)--------------")
print(f"Accuracy(lmbd = {lmbd}, eta = {eta}) = {val_acc_optimal:.3f}")
# Out:
# --------- Optimal Fit (according to Validation Accuracy)--------------
# Accuracy(lmbd = 0.01, eta = 0.001) = 0.905

# %% [markdown]
# ### Comparison Activation Functions vs. Batch Size (M)  with CNN model

# %%
tf.keras.utils.set_random_seed(seed) # must include for reproducibility 



# Defining parameter-space to search for optimal fit
batch_size_list = np.linspace(5,50,10)   # forlag1 (5, 100, 20) forslag2 (10,100,10)
act_func_list = ['relu', 'leaky_relu'] 
# act_func-string must match tf.keras.activations found at https://www.tensorflow.org/api_docs/python/tf/keras/activations


print("batch_size_list = ", batch_size_list)
print("act_func_list  = ", act_func_list)



CNN_model_list = []
fit_list       = []
for batch_size in batch_size_list:
    for act_func in act_func_list:
        fold = 0
        fit  = []
        for train_idx, val_idx in kf.split(train_df): # performing K-Fold
            # Split the data
            tr_fold, v_fold = train_df.iloc[train_idx], train_df.iloc[val_idx]

            ID_tr_gen = ImageDataGenerator()
            ID_v_gen  =  ImageDataGenerator()
            train_fold = ID_tr_gen.flow_from_dataframe(tr_fold, x_col='filepaths', y_col='labels', target_size=img_size, class_mode='categorical', color_mode='rgb', shuffle= True, batch_size=batch_size_IDG)
            val_fold   = ID_v_gen.flow_from_dataframe(v_fold, x_col='filepaths', y_col='labels', target_size=img_size, class_mode='categorical', color_mode='rgb', shuffle= True, batch_size=batch_size_IDG)

            
            # Initialize a new model for each fold
            CNN_model = CNN(eta, lmbd, n_filters, n_conv, n_pool, n_neurons, act_func, optimizer)
            #print("------------------------- SUMMARY --------------------------")
            #CNN_model.summary()

            # Train on current fold
            print(f'\nFold {fold + 1} - batch_size = {batch_size}, act_func = {act_func} \n\n')
            fit_fold = CNN_model.fit(x= train_fold, epochs=epochs, batch_size=batch_size, validation_data=val_fold, verbose=0, callbacks=[early_stopping])
            
            fit.append(fit_fold)
            fold += 1
            tf.keras.backend.clear_session()
            gc.collect()

        # Save results
        fit_list.append([fit, batch_size, act_func])
# Out:
# batch_size_list =  [ 5. 10. 15. 20. 25. 30. 35. 40. 45. 50.]
# act_func_list  =  ['relu', 'leaky_relu']
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - batch_size = 5.0, act_func = relu
#
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - batch_size = 5.0, act_func = relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - batch_size = 5.0, act_func = relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - batch_size = 5.0, act_func = relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - batch_size = 5.0, act_func = relu
#
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - batch_size = 5.0, act_func = leaky_relu
#
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - batch_size = 5.0, act_func = leaky_relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - batch_size = 5.0, act_func = leaky_relu
# 2024-11-21 11:46:25.917197: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'input_reduce_select_fusion_2', 192 bytes spill stores, 192 bytes spill loads
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - batch_size = 5.0, act_func = leaky_relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - batch_size = 5.0, act_func = leaky_relu
#
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - batch_size = 10.0, act_func = relu
#
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - batch_size = 10.0, act_func = relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - batch_size = 10.0, act_func = relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - batch_size = 10.0, act_func = relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - batch_size = 10.0, act_func = relu
#
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - batch_size = 10.0, act_func = leaky_relu
#
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - batch_size = 10.0, act_func = leaky_relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - batch_size = 10.0, act_func = leaky_relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - batch_size = 10.0, act_func = leaky_relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - batch_size = 10.0, act_func = leaky_relu
#
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - batch_size = 15.0, act_func = relu
#
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - batch_size = 15.0, act_func = relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - batch_size = 15.0, act_func = relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - batch_size = 15.0, act_func = relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - batch_size = 15.0, act_func = relu
#
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - batch_size = 15.0, act_func = leaky_relu
#
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - batch_size = 15.0, act_func = leaky_relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - batch_size = 15.0, act_func = leaky_relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - batch_size = 15.0, act_func = leaky_relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - batch_size = 15.0, act_func = leaky_relu
#
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - batch_size = 20.0, act_func = relu
#
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - batch_size = 20.0, act_func = relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - batch_size = 20.0, act_func = relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - batch_size = 20.0, act_func = relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - batch_size = 20.0, act_func = relu
#
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - batch_size = 20.0, act_func = leaky_relu
#
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - batch_size = 20.0, act_func = leaky_relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - batch_size = 20.0, act_func = leaky_relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - batch_size = 20.0, act_func = leaky_relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - batch_size = 20.0, act_func = leaky_relu
#
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - batch_size = 25.0, act_func = relu
#
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - batch_size = 25.0, act_func = relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - batch_size = 25.0, act_func = relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - batch_size = 25.0, act_func = relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - batch_size = 25.0, act_func = relu
#
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - batch_size = 25.0, act_func = leaky_relu
#
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - batch_size = 25.0, act_func = leaky_relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - batch_size = 25.0, act_func = leaky_relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - batch_size = 25.0, act_func = leaky_relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - batch_size = 25.0, act_func = leaky_relu
#
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - batch_size = 30.0, act_func = relu
#
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - batch_size = 30.0, act_func = relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - batch_size = 30.0, act_func = relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - batch_size = 30.0, act_func = relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - batch_size = 30.0, act_func = relu
#
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - batch_size = 30.0, act_func = leaky_relu
#
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - batch_size = 30.0, act_func = leaky_relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - batch_size = 30.0, act_func = leaky_relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - batch_size = 30.0, act_func = leaky_relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - batch_size = 30.0, act_func = leaky_relu
#
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - batch_size = 35.0, act_func = relu
#
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - batch_size = 35.0, act_func = relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - batch_size = 35.0, act_func = relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - batch_size = 35.0, act_func = relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - batch_size = 35.0, act_func = relu
#
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - batch_size = 35.0, act_func = leaky_relu
#
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - batch_size = 35.0, act_func = leaky_relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - batch_size = 35.0, act_func = leaky_relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - batch_size = 35.0, act_func = leaky_relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - batch_size = 35.0, act_func = leaky_relu
#
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - batch_size = 40.0, act_func = relu
#
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - batch_size = 40.0, act_func = relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - batch_size = 40.0, act_func = relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - batch_size = 40.0, act_func = relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - batch_size = 40.0, act_func = relu
#
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - batch_size = 40.0, act_func = leaky_relu
#
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - batch_size = 40.0, act_func = leaky_relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - batch_size = 40.0, act_func = leaky_relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - batch_size = 40.0, act_func = leaky_relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - batch_size = 40.0, act_func = leaky_relu
#
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - batch_size = 45.0, act_func = relu
#
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - batch_size = 45.0, act_func = relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - batch_size = 45.0, act_func = relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - batch_size = 45.0, act_func = relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - batch_size = 45.0, act_func = relu
#
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - batch_size = 45.0, act_func = leaky_relu
#
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - batch_size = 45.0, act_func = leaky_relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - batch_size = 45.0, act_func = leaky_relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - batch_size = 45.0, act_func = leaky_relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - batch_size = 45.0, act_func = leaky_relu
#
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - batch_size = 50.0, act_func = relu
#
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - batch_size = 50.0, act_func = relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - batch_size = 50.0, act_func = relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - batch_size = 50.0, act_func = relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - batch_size = 50.0, act_func = relu
#
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - batch_size = 50.0, act_func = leaky_relu
#
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - batch_size = 50.0, act_func = leaky_relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - batch_size = 50.0, act_func = leaky_relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - batch_size = 50.0, act_func = leaky_relu
#
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - batch_size = 50.0, act_func = leaky_relu

# %% [markdown]
# ### Performance Scores: Activation Functions vs. Batch Size (M)

# %%
string1 = 'Batch Size'
string2 = 'Activation Function'
png_name = 'val_acc_' + string1 + "_" + string2
plot_accuracy_evoluton(fit_list, string1, string2, png_name)


var1 = batch_size_list
var2 = act_func_list
png_name = 'heatmap_val_acc' + string1 + "_" + string2
index_max_val_acc, index_max_2d =  plot_heatmap(fit_list, var1, var2, string1, string2, png_name)




# ---------------------------- Selecting optimal fit for lmbd vs. eta (according to Validation Accuracy)
# Save parameters for future use 
fit, batch_size, act_func = fit_list[index_max_val_acc] 

val_acc_optimal = np.mean([f.history['val_acc'] for f in fit], axis=0)[-1] # calculating mean val_acc for all folds

print("--------- Optimal Fit (according to Validation Accuracy)--------------")
print(f"Accuracy(batch_size = {batch_size}, act_func = {act_func}) = {val_acc_optimal:.3f}")
# Out:
# --------- Optimal Fit (according to Validation Accuracy)--------------
# Accuracy(batch_size = 45.0, act_func = leaky_relu) = 0.921

# %%
tf.keras.utils.set_random_seed(seed) # must include for reproducibility 

# Defining parameter-space to search for optimal fit
n_neurons_list = np.linspace(20,90,8)
extra_dense_layer_list = [None, 1]
# had to limit n_neurons_list from 10 elements to 7 because of memory issues
# had to limit extra_dense_layer_list from 4 elements to 3 because of memory issues 

batch_size_IDG = 1 # lower batch_size for ImageDataGenerator because of memory issues



print("n_neurons_list = ", n_neurons_list)
print("extra_dense_layer_list  = ", extra_dense_layer_list)


CNN_model_list = []
fit_list       = []
for n_neurons in n_neurons_list:
    for extra_dense_layer in extra_dense_layer_list:
        fold = 0
        fit  = []
        for train_idx, val_idx in kf.split(train_df): # performing K-Fold
            # Split the data
            tr_fold, v_fold = train_df.iloc[train_idx], train_df.iloc[val_idx]

            ID_tr_gen = ImageDataGenerator()
            ID_v_gen  =  ImageDataGenerator()
            train_fold = ID_tr_gen.flow_from_dataframe(tr_fold, x_col='filepaths', y_col='labels', target_size=img_size, class_mode='categorical', color_mode='rgb', shuffle= True, batch_size=batch_size_IDG)
            val_fold   = ID_v_gen.flow_from_dataframe(v_fold, x_col='filepaths', y_col='labels', target_size=img_size, class_mode='categorical', color_mode='rgb', shuffle= True, batch_size=batch_size_IDG)

            
            # Initialize a new model for each fold
            CNN_model = CNN(eta, lmbd, n_filters, n_conv, n_pool, int(n_neurons), act_func, optimizer, extra_dense_layer)
            #print("------------------------- SUMMARY --------------------------")
            #CNN_model.summary()

            # Train on current fold
            print(f'\nFold {fold + 1} - n_neurons = {n_neurons}, extra_dense_layer = {extra_dense_layer}\n')
            fit_fold = CNN_model.fit(x= train_fold, epochs=epochs, batch_size=batch_size, validation_data=val_fold, verbose=0, callbacks=[early_stopping])
            
            fit.append(fit_fold)
            fold += 1
            tf.keras.backend.clear_session()
            gc.collect()

        # Save results
        fit_list.append([fit, n_neurons, extra_dense_layer])
# Out:
# n_neurons_list =  [20. 30. 40. 50. 60. 70. 80. 90.]
# extra_dense_layer_list  =  [None, 1]
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - n_neurons = 20.0, extra_dense_layer = None
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - n_neurons = 20.0, extra_dense_layer = None
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - n_neurons = 20.0, extra_dense_layer = None
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - n_neurons = 20.0, extra_dense_layer = None
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - n_neurons = 20.0, extra_dense_layer = None
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - n_neurons = 20.0, extra_dense_layer = 1
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - n_neurons = 20.0, extra_dense_layer = 1
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - n_neurons = 20.0, extra_dense_layer = 1
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - n_neurons = 20.0, extra_dense_layer = 1
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - n_neurons = 20.0, extra_dense_layer = 1
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - n_neurons = 30.0, extra_dense_layer = None
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - n_neurons = 30.0, extra_dense_layer = None
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - n_neurons = 30.0, extra_dense_layer = None
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - n_neurons = 30.0, extra_dense_layer = None
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - n_neurons = 30.0, extra_dense_layer = None
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - n_neurons = 30.0, extra_dense_layer = 1
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - n_neurons = 30.0, extra_dense_layer = 1
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - n_neurons = 30.0, extra_dense_layer = 1
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - n_neurons = 30.0, extra_dense_layer = 1
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - n_neurons = 30.0, extra_dense_layer = 1
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - n_neurons = 40.0, extra_dense_layer = None
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - n_neurons = 40.0, extra_dense_layer = None
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - n_neurons = 40.0, extra_dense_layer = None
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - n_neurons = 40.0, extra_dense_layer = None
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - n_neurons = 40.0, extra_dense_layer = None
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - n_neurons = 40.0, extra_dense_layer = 1
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - n_neurons = 40.0, extra_dense_layer = 1
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - n_neurons = 40.0, extra_dense_layer = 1
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - n_neurons = 40.0, extra_dense_layer = 1
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - n_neurons = 40.0, extra_dense_layer = 1
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - n_neurons = 50.0, extra_dense_layer = None
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - n_neurons = 50.0, extra_dense_layer = None
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - n_neurons = 50.0, extra_dense_layer = None
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - n_neurons = 50.0, extra_dense_layer = None
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - n_neurons = 50.0, extra_dense_layer = None
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - n_neurons = 50.0, extra_dense_layer = 1
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - n_neurons = 50.0, extra_dense_layer = 1
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - n_neurons = 50.0, extra_dense_layer = 1
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - n_neurons = 50.0, extra_dense_layer = 1
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - n_neurons = 50.0, extra_dense_layer = 1
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - n_neurons = 60.0, extra_dense_layer = None
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - n_neurons = 60.0, extra_dense_layer = None
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - n_neurons = 60.0, extra_dense_layer = None
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - n_neurons = 60.0, extra_dense_layer = None
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - n_neurons = 60.0, extra_dense_layer = None
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - n_neurons = 60.0, extra_dense_layer = 1
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - n_neurons = 60.0, extra_dense_layer = 1
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - n_neurons = 60.0, extra_dense_layer = 1
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - n_neurons = 60.0, extra_dense_layer = 1
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - n_neurons = 60.0, extra_dense_layer = 1
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - n_neurons = 70.0, extra_dense_layer = None
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - n_neurons = 70.0, extra_dense_layer = None
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - n_neurons = 70.0, extra_dense_layer = None
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - n_neurons = 70.0, extra_dense_layer = None
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - n_neurons = 70.0, extra_dense_layer = None
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - n_neurons = 70.0, extra_dense_layer = 1
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - n_neurons = 70.0, extra_dense_layer = 1
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - n_neurons = 70.0, extra_dense_layer = 1
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - n_neurons = 70.0, extra_dense_layer = 1
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - n_neurons = 70.0, extra_dense_layer = 1
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - n_neurons = 80.0, extra_dense_layer = None
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - n_neurons = 80.0, extra_dense_layer = None
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - n_neurons = 80.0, extra_dense_layer = None
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - n_neurons = 80.0, extra_dense_layer = None
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - n_neurons = 80.0, extra_dense_layer = None
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - n_neurons = 80.0, extra_dense_layer = 1
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - n_neurons = 80.0, extra_dense_layer = 1
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - n_neurons = 80.0, extra_dense_layer = 1
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - n_neurons = 80.0, extra_dense_layer = 1
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - n_neurons = 80.0, extra_dense_layer = 1
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - n_neurons = 90.0, extra_dense_layer = None
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - n_neurons = 90.0, extra_dense_layer = None
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - n_neurons = 90.0, extra_dense_layer = None
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - n_neurons = 90.0, extra_dense_layer = None
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - n_neurons = 90.0, extra_dense_layer = None
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 1 - n_neurons = 90.0, extra_dense_layer = 1
#
# Found 453 validated image filenames belonging to 6 classes.
# Found 114 validated image filenames belonging to 6 classes.
#
# Fold 2 - n_neurons = 90.0, extra_dense_layer = 1
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 3 - n_neurons = 90.0, extra_dense_layer = 1
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 4 - n_neurons = 90.0, extra_dense_layer = 1
#
# Found 454 validated image filenames belonging to 6 classes.
# Found 113 validated image filenames belonging to 6 classes.
#
# Fold 5 - n_neurons = 90.0, extra_dense_layer = 1

# %%
string1 = 'n_neurons'
string2 = 'extra_dense_layer'
png_name = 'val_acc_' + string1 + "_" + string2
plot_accuracy_evoluton(fit_list, string1, string2, png_name)

var1 = n_neurons_list
var2 = extra_dense_layer_list
png_name = 'heatmap_val_acc' + string1 + "_" + string2
index_max_val_acc, index_max_2d =  plot_heatmap(fit_list, var1, var2, string1, string2, png_name)




# ---------------------------- Selecting optimal fit for lmbd vs. eta (according to Validation Accuracy)
# Save parameters for future use 
fit, n_neurons, extra_dense_layer = fit_list[index_max_val_acc] 

val_acc_optimal = np.mean([f.history['val_acc'] for f in fit], axis=0)[-1] # calculating mean val_acc for all folds

print("--------- Optimal Fit (according to Validation Accuracy)--------------")
print(f"Accuracy(n_neurons = {n_neurons}, extra_dense_layer = {extra_dense_layer}) = {val_acc_optimal:.3f}")
# Out:
# --------- Optimal Fit (according to Validation Accuracy)--------------
# Accuracy(n_neurons = 20.0, extra_dense_layer = 1) = 0.905
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # Running Final Model

# %%
# ---------------- Making Final Model
epochs = 1000 # final run

CNN_model = CNN(eta, lmbd, n_filters, n_conv, n_pool, int(n_neurons), act_func, optimizer, extra_dense_layer)
print("------------------------- SUMMARY --------------------------")
CNN_model.summary()

fit = CNN_model.fit(x= train_gen, epochs=epochs, batch_size=batch_size, validation_data=test_gen, verbose=1, callbacks=[early_stopping])

# Define needed variables
tr_acc = fit.history['acc']
tr_loss = fit.history['loss']
val_acc = fit.history['val_acc']
val_loss = fit.history['val_loss']
index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]
index_acc = np.argmax(val_acc)
acc_highest = val_acc[index_acc]
Epochs = [i+1 for i in range(len(tr_acc))]
loss_label = f'best epoch = {str(index_loss + 1)}'
acc_label = f'best epoch = {str(index_acc + 1)}'
# Out:
# ------------------------- SUMMARY --------------------------
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 224, 224, 6)    │           168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 112, 112, 6)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 112, 112, 12)   │           660 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 28, 28, 12)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 28, 28, 24)     │         2,616 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 3, 3, 24)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 216)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 20)             │         4,340 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 20)             │           420 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 6)              │           126 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,330 (32.54 KB)
#  Trainable params: 8,330 (32.54 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/1000
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - acc: 0.2238 - loss: 13.3366 - val_acc: 0.3975 - val_loss: 2.4114
# Epoch 2/1000
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - acc: 0.4322 - loss: 2.2882 - val_acc: 0.6066 - val_loss: 1.8160
# Epoch 3/1000
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - acc: 0.6641 - loss: 1.6754 - val_acc: 0.7459 - val_loss: 1.5716
# Epoch 4/1000
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - acc: 0.7488 - loss: 1.4653 - val_acc: 0.7746 - val_loss: 1.4128
# Epoch 5/1000
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - acc: 0.8343 - loss: 1.2616 - val_acc: 0.7541 - val_loss: 1.4389
# Epoch 6/1000
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - acc: 0.8528 - loss: 1.2269 - val_acc: 0.8156 - val_loss: 1.3783
# Epoch 7/1000
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - acc: 0.9023 - loss: 1.0848 - val_acc: 0.7828 - val_loss: 1.3989
# Epoch 8/1000
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - acc: 0.9143 - loss: 1.0493 - val_acc: 0.8033 - val_loss: 1.3639
# Epoch 9/1000
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - acc: 0.9182 - loss: 1.0304 - val_acc: 0.8443 - val_loss: 1.2507
# Epoch 10/1000
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - acc: 0.9490 - loss: 0.9433 - val_acc: 0.8566 - val_loss: 1.2554
# Epoch 11/1000
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - acc: 0.9533 - loss: 0.9440 - val_acc: 0.8033 - val_loss: 1.4240
# Epoch 12/1000
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - acc: 0.9353 - loss: 0.9538 - val_acc: 0.8443 - val_loss: 1.2473
# Epoch 13/1000
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - acc: 0.9555 - loss: 0.8810 - val_acc: 0.8484 - val_loss: 1.3300
# Epoch 14/1000
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - acc: 0.9713 - loss: 0.8626 - val_acc: 0.8402 - val_loss: 1.2267
# Epoch 15/1000
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 139ms/step - acc: 0.9707 - loss: 0.8278 - val_acc: 0.8525 - val_loss: 1.2695
# Epoch 16/1000
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 14s 198ms/step - acc: 0.9847 - loss: 0.7729 - val_acc: 0.7705 - val_loss: 1.5683
# Epoch 17/1000
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - acc: 0.9495 - loss: 0.8733 - val_acc: 0.8320 - val_loss: 1.4104
# Epoch 18/1000
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 32s 450ms/step - acc: 0.9568 - loss: 0.8707 - val_acc: 0.8402 - val_loss: 1.2269
# Epoch 19/1000
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 159s 2s/step - acc: 0.9694 - loss: 0.7634 - val_acc: 0.8074 - val_loss: 1.3819
# Epoch 20/1000
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 45s 623ms/step - acc: 0.9532 - loss: 0.8551 - val_acc: 0.8607 - val_loss: 1.1820
# Epoch 21/1000
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - acc: 0.9822 - loss: 0.7312 - val_acc: 0.8607 - val_loss: 1.2488
# Epoch 22/1000
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 60s 842ms/step - acc: 0.9926 - loss: 0.6924 - val_acc: 0.8566 - val_loss: 1.2307
# Epoch 23/1000
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - acc: 0.9688 - loss: 0.7654 - val_acc: 0.7951 - val_loss: 1.4677
# Epoch 24/1000
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - acc: 0.9755 - loss: 0.7174 - val_acc: 0.8607 - val_loss: 1.2141
# Epoch 25/1000
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - acc: 0.9921 - loss: 0.6575 - val_acc: 0.8648 - val_loss: 1.2051
# Epoch 26/1000
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - acc: 0.9974 - loss: 0.6369 - val_acc: 0.8648 - val_loss: 1.1963
# Epoch 27/1000
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 6s 86ms/step - acc: 0.9929 - loss: 0.6342 - val_acc: 0.8730 - val_loss: 1.1066
# Epoch 28/1000
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 21s 294ms/step - acc: 1.0000 - loss: 0.6077 - val_acc: 0.8811 - val_loss: 1.1191
# Epoch 29/1000
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 22s 303ms/step - acc: 1.0000 - loss: 0.5902 - val_acc: 0.8852 - val_loss: 1.0846
# Epoch 30/1000
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 26s 368ms/step - acc: 1.0000 - loss: 0.5765 - val_acc: 0.8934 - val_loss: 1.0630
# Epoch 31/1000
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 159s 2s/step - acc: 1.0000 - loss: 0.5647 - val_acc: 0.8770 - val_loss: 1.0816
# Epoch 32/1000
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 126s 2s/step - acc: 1.0000 - loss: 0.5507 - val_acc: 0.8770 - val_loss: 1.0475
# Epoch 33/1000
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 297s 4s/step - acc: 1.0000 - loss: 0.5388 - val_acc: 0.8811 - val_loss: 1.0214
# Epoch 34/1000
# 22/71 ━━━━━━━━━━━━━━━━━━━━ 1:27 2s/step - acc: 1.0000 - loss: 0.5268

# %% [markdown]
# ## Performance Scores
# ### Optimal $\lambda$, $\eta$, (should be Activation Functions, Batch Size (M), # Hidden Layers, # Hidden Nodes)

# %% [markdown]
# #### Training & Validation - Cross Entropy Loss

# %%
plt.figure(figsize= (7, 12))
plt.style.use('fivethirtyeight')

plt.plot(Epochs, tr_loss, 'purple', label= 'Training loss')
plt.plot(Epochs, val_loss, 'gold', label= 'Validation loss')

parameter_string = rf"$\lambda$ = {lmbd}  &  $\eta$ = {eta}   &   Batch Size = {batch_size}   &   Activation Functions = {act_func}   &   Extra Dense Layers = {extra_dense_layer}   &   n_neurons = {n_neurons} "
parameter_string_wrapped = "\n \n \n" + rf"$\lambda$ = {lmbd}  &  $\eta$ = {eta}   &   Batch Size = {batch_size} " + "\n" + f"  Activation Functions = {act_func} " + "\n" + f"Extra Dense Layers = {extra_dense_layer}   &   n_neurons = {n_neurons} "
#plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'darkblue', label= loss_label)
plt.suptitle('CNN      -      Training and Validation Loss \n' , fontsize=fontsize)
plt.title(parameter_string_wrapped, fontsize=fontsize-5)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout
plt.savefig("CNN_plots/train_val_loss.png")

# %% [markdown]
# #### Training & Validation - Accuracy

# %%
plt.figure(figsize= (7, 12))
plt.style.use('fivethirtyeight')

plt.plot(Epochs, tr_acc, 'purple', label= 'Training Accuracy')
plt.plot(Epochs, val_acc, 'gold', label= 'Validation Accuracy')
#plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'darkblue', label= acc_label)
plt.suptitle('CNN      -      Training and Validation Accuracy', fontsize=fontsize)
plt.title(parameter_string_wrapped, fontsize=fontsize-5)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout
plt.savefig("CNN_plots/train_val_acc.png")

# %% [markdown]
# ### Make Predictions

# %%
# Make Predictions
preds  = CNN_model.predict(test_gen) # Probabilities 6 labes   shape (122, 6)

y_pred = np.argmax(preds, axis=1)    # Most probable label     shape (122,)


# -------------------------.-- Plot Confusion matrix --------------------------------------
g_dict = test_gen.class_indices
classes = list(g_dict.keys())

cm = confusion_matrix(test_gen.classes, y_pred, normalize='true') 
# normalize = 'true' -> get respective accuracy scores  
# sum each row = 1 

# Create a heat map
plt.figure(figsize= (7, 12))
sns.heatmap(cm, annot=True, cmap='Blues', xticklabels=classes, yticklabels=classes, fmt='.3f') #,  fmt='d')


plt.suptitle('CNN      -      Confusion Matrix', fontsize=fontsize)
plt.title(parameter_string_wrapped, fontsize=fontsize-5)
plt.xlabel('Predicted Classes')
plt.ylabel('True Classes')

# Modify the rotation of axis labels
plt.xticks(rotation=45)  # Rotation of x-axis labels
plt.yticks(rotation=0)   # Rotation of y-axis labels

plt.savefig("CNN_plots/confusion_matrix.png")
plt.show()

# %% [markdown]
# ### Final Evaluation Model

# %%
train_score = CNN_model.evaluate(train_gen, verbose=1)
test_score  = CNN_model.evaluate(test_gen, verbose=1)
# .evaluate gives list of score ["Cross_Entropy_Loss", "Accuracy"]

print("Train Loss: ", train_score[0])
print("Train Accuracy: ", train_score[1])
print('-' * 20)
print("Test Loss: ", test_score[0])
print("Test Accuracy: ", test_score[1])
